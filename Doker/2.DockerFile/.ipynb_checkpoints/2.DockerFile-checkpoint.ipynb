# %% [markdown]
# <img src="http://lssds.aura-astronomy.org/winter_school/sites/default/files/sods_atfdds_header01.jpg" alt="La Serena School for Data Science: Applied Tools for Data-driven Sciences" />

# %% [markdown]
# ## 1. Introduction:
#
# A Dockerfile is a plain text configuration file used to define the steps for building a Docker image. It is a critical component of the Docker ecosystem, allowing developers to automate the process of creating reproducible and consistent container images. Dockerfiles are used to encapsulate the configuration and dependencies of an application or service, making it easier to package, distribute, and deploy software as containers.
#
# The Dockerfile typically includes a series of instructions, each on a separate line, that dictate how the image should be constructed. The Docker engine interprets these instructions and builds the image layer by layer. When a new container is created from the image, the file system is constructed based on these layers, making it efficient and fast.
#
# Below is an example of a Dockerfile for creating a Jupyter Notebook server using the official Jupyter Docker Stacks image:

# %%
# !cat Dockerfile
# Out:
# FROM jupyter/base-notebook:latest
#
# WORKDIR /home/jovyan/work
#
# COPY . /home/jovyan/work
#
# EXPOSE 8889
#
# RUN pip install pandas matplotlib
#
# CMD ["jupyter", "notebook", "--ip=0.0.0.0", "--port=8889","--no-browser"]

# %% [markdown]
# ## 2. key components of a Dockerfile:

# %% [markdown]
# - **2.1 Base Image:**
#
# The Dockerfile starts with specifying the base image upon which the custom image will be built. The base image is the starting point for your application's image and contains the operating system and other pre-installed software or libraries.
# The base image is defined using the FROM instruction. For example:

# %%
FROM jupyter/minimal-notebook

# %% [markdown]
# - **2.2 Environment Configuration:**
#
# The Dockerfile can include environment configuration settings that define variables, specify working directories, and set other runtime behaviors.
# Environment configuration is set using the ENV instruction. For example:

# %%
ENV NODE_ENV=production

# %% [markdown]
# - **2.3 Copying Files:**
#
# The COPY instruction allows you to copy files and directories from the host system to the image's file system. This step is essential for adding your application code and any necessary resources to the image.
# For example:

# %%
COPY . /app

# %% [markdown]
# - **2.4 Running Commands:**
#
# The RUN instruction is used to execute commands within the image's file system. This is commonly used to install packages, dependencies, and other software needed for your application to run.
#
# For example, for a Node.js application, you might run the following command to install Node.js dependencies:

# %%
RUN npm install

# %% [markdown]
# - **2.5 Exposing Ports:**
#
# The EXPOSE instruction is used to specify which ports the container should listen on. It does not actually publish the ports but serves as documentation for developers and users of the image.
#
# For example, to indicate that the container listens on port 3000, you would add the following line:

# %%
EXPOSE 3000

# %% [markdown]
# - **2.6 Container Execution Command:**
#
# The ***CMD*** or ***ENTRYPOINT*** instruction defines the command that should be executed when a container is started from the image. This is usually the main process of your application.
#
# For example, for a Node.js application, you might use:

# %%
CMD ["node", "app.js"]

# %% [markdown]
# Once you have defined your Dockerfile, you can use the ***docker build*** command to build the Docker image based on the instructions provided in the file. This will create a container image that contains all the specified configurations, dependencies, and code necessary to run your application.
#
# Dockerfiles are a powerful tool for creating consistent and reproducible container images. They allow developers to define the exact environment needed for their applications, making it easier to share and distribute software across different environments and systems.

# %% [markdown]
# ## 3. Create a step-by-step Dockerfile:
#
# Let's create a step-by-step Dockerfile for a Jupyter Notebook server using the official Jupyter Docker Stacks image:

# %% [markdown]
# - **3.1: Choose the Base Image**
#
# We'll use the official Jupyter Notebook image from Jupyter Docker Stacks as the base image. This image includes the basic Jupyter Notebook installation.
# Choose the tag for the base image based on your requirements. In this example, we'll use the ***base-notebook*** tag.

# %%
FROM jupyter/base-notebook:latest

# %% [markdown]
# - **3.2: Set the Working Directory**
#
# It's a good practice to set the working directory inside the container where your Jupyter Notebook files will be located.
# We'll set it to ***/home/jovyan/work***, which is the default directory for Jupyter Notebook files in the base image

# %%
WORKDIR /home/jovyan/work

# %% [markdown]
# - **3.3: Copy Notebook Files**
#
# Next, we'll copy the Jupyter Notebook files from the local directory (where the Dockerfile is located) into the container's working directory.
# Make sure that your Jupyter Notebook files (e.g., ***.ipynb files***) are present in the same directory as the Dockerfile.

# %%
COPY . /home/jovyan/work

# %% [markdown]
# - **3.4: Expose Port**
#
# The Jupyter Notebook runs on port 8888 by default but there are cases where this port may be used, so we will change it to 8889. To access it from the host machine, we need to expose this port from the container.

# %%
EXPOSE 8889

# %% [markdown]
# - **3.5: Install Additional Packages (Optional)**
#
# If your Jupyter Notebooks require additional Python packages or libraries, you can install them using pip or conda.
# In this example, we'll use pip to install pandas and matplotlib.

# %%
RUN pip install pandas matplotlib

# %% [markdown]
# - **3.6: Start Jupyter Notebook Server**
#
# Finally, we'll add the command to start the Jupyter Notebook server when the container is run.
# The --ip=0.0.0.0 option allows access to the server from all IP addresses, and --no-browser prevents Jupyter from trying to open a browser inside the container.

# %%
CMD ["jupyter", "notebook", "--ip=0.0.0.0", "--port=8889","--no-browser"]

# %% [markdown]
# The complete Dockerfile will look like this:

# %%
# !cat Dockerfile
# Out:
# FROM jupyter/base-notebook:latest
#
# WORKDIR /home/jovyan/work
#
# COPY . /home/jovyan/work
#
# EXPOSE 8889
#
# RUN pip install pandas matplotlib
#
# CMD ["jupyter", "notebook", "--ip=0.0.0.0", "--port=8889","--no-browser"]

# %% [markdown]
# To build the Docker image, save the above code into a file named Dockerfile in the same directory as your Jupyter Notebook files. Then, open a terminal or command prompt, navigate to the directory containing the Dockerfile, and run the following command:

# %%
# !docker build -t jupyter_server .
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (2/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
# [+] Building 0.3s (4/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
# [+] Building 0.4s (6/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.1s
# [+] Building 0.6s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                0.1s
# [+] Building 0.7s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                0.3s
# [+] Building 0.9s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                0.4s
# [+] Building 1.0s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                0.6s
# [+] Building 1.2s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                0.7s
# [+] Building 1.3s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                0.9s
# [+] Building 1.5s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                1.0s
# [+] Building 1.6s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                1.2s
# [+] Building 1.8s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                1.3s
# [+] Building 1.9s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                1.5s
# [+] Building 2.1s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                1.6s
# [+] Building 2.2s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                1.8s
# [+] Building 2.4s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                1.9s
# [+] Building 2.5s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                2.1s
# [+] Building 2.7s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                2.2s
# [+] Building 2.8s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                2.4s
# [+] Building 3.0s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                2.5s
#  => => # Collecting pandas
#  => => #   Obtaining dependency information for pandas from https://files.pytho
#  => => # nhosted.org/packages/d0/28/88b81881c056376254618fad622a5e94b5126db8c61
#  => => # 157ea1910cd1c040a/pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl.metadata
# [+] Building 3.1s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                2.7s
#  => => #   Obtaining dependency information for pandas from https://files.pytho
#  => => # nhosted.org/packages/d0/28/88b81881c056376254618fad622a5e94b5126db8c61
#  => => # 157ea1910cd1c040a/pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl.metadata
#  => => #   Downloading pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux
#  => => # 2014_x86_64.whl.metadata (18 kB)
# [+] Building 3.3s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                2.8s
#  => => #   Obtaining dependency information for pandas from https://files.pytho
#  => => # nhosted.org/packages/d0/28/88b81881c056376254618fad622a5e94b5126db8c61
#  => => # 157ea1910cd1c040a/pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl.metadata
#  => => #   Downloading pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux
#  => => # 2014_x86_64.whl.metadata (18 kB)
# [+] Building 3.4s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                2.9s
#  => => # nhosted.org/packages/d0/28/88b81881c056376254618fad622a5e94b5126db8c61
#  => => # 157ea1910cd1c040a/pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl.metadata
#  => => #   Downloading pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux
#  => => # 2014_x86_64.whl.metadata (18 kB)
#  => => # Collecting matplotlib
# [+] Building 3.5s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                3.1s
#  => => #   Obtaining dependency information for matplotlib from https://files.p
#  => => # ythonhosted.org/packages/4f/d7/3303f11188122f66c940056f162d030992e7fbc
#  => => # 9c702869bab163e85156b/matplotlib-3.7.2-cp311-cp311-manylinux_2_17_x86_
#  => => # 64.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading matplotlib-3.7.2-cp311-cp311-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl.metadata (5.6 kB)
# [+] Building 3.6s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                3.2s
#  => => # Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/li
#  => => # b/python3.11/site-packages (from pandas) (2.8.2)
#  => => # Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.
#  => => # 11/site-packages (from pandas) (2023.3)
#  => => # Collecting tzdata>=2022.1 (from pandas)
#  => => #   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# [+] Building 3.8s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                3.3s
#  => => # Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.
#  => => # 11/site-packages (from pandas) (2023.3)
#  => => # Collecting tzdata>=2022.1 (from pandas)
#  => => #   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 2.9 MB/s e
#  => => # ta 0:00:00
# [+] Building 3.9s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                3.5s
#  => => # Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.
#  => => # 11/site-packages (from pandas) (2023.3)
#  => => # Collecting tzdata>=2022.1 (from pandas)
#  => => #   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 2.9 MB/s e
#  => => # ta 0:00:00
# [+] Building 4.1s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                3.6s
#  => => # Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.
#  => => # 11/site-packages (from pandas) (2023.3)
#  => => # Collecting tzdata>=2022.1 (from pandas)
#  => => #   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 2.9 MB/s e
#  => => # ta 0:00:00
# [+] Building 4.2s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                3.8s
#  => => # Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.
#  => => # 11/site-packages (from pandas) (2023.3)
#  => => # Collecting tzdata>=2022.1 (from pandas)
#  => => #   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 2.9 MB/s e
#  => => # ta 0:00:00
# [+] Building 4.4s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                3.9s
#  => => #   Obtaining dependency information for numpy>=1.21.0 from https://file
#  => => # s.pythonhosted.org/packages/32/6a/65dbc57a89078af9ff8bfcd4c0761a50172d
#  => => # 90192eaeb1b6f56e5fbf1c3d/numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_6
#  => => # 4.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_64.manylinux
#  => => # 2014_x86_64.whl.metadata (5.6 kB)
# [+] Building 4.5s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                4.1s
#  => => #   Obtaining dependency information for numpy>=1.21.0 from https://file
#  => => # s.pythonhosted.org/packages/32/6a/65dbc57a89078af9ff8bfcd4c0761a50172d
#  => => # 90192eaeb1b6f56e5fbf1c3d/numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_6
#  => => # 4.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_64.manylinux
#  => => # 2014_x86_64.whl.metadata (5.6 kB)
# [+] Building 4.6s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                4.2s
#  => => # iles.pythonhosted.org/packages/d8/23/8d968922459b1c8a2c6ffca28fac00324
#  => => # b06b3a0633be2a39b0b1c3f84ab/contourpy-1.1.0-cp311-cp311-manylinux_2_17
#  => => # _x86_64.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manyli
#  => => # nux2014_x86_64.whl.metadata (5.7 kB)
#  => => # Collecting cycler>=0.10 (from matplotlib)
# [+] Building 4.8s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                4.4s
#  => => # b06b3a0633be2a39b0b1c3f84ab/contourpy-1.1.0-cp311-cp311-manylinux_2_17
#  => => # _x86_64.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manyli
#  => => # nux2014_x86_64.whl.metadata (5.7 kB)
#  => => # Collecting cycler>=0.10 (from matplotlib)
#  => => #   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# [+] Building 5.0s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                4.5s
#  => => # b06b3a0633be2a39b0b1c3f84ab/contourpy-1.1.0-cp311-cp311-manylinux_2_17
#  => => # _x86_64.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manyli
#  => => # nux2014_x86_64.whl.metadata (5.7 kB)
#  => => # Collecting cycler>=0.10 (from matplotlib)
#  => => #   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# [+] Building 5.1s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                4.7s
#  => => # b06b3a0633be2a39b0b1c3f84ab/contourpy-1.1.0-cp311-cp311-manylinux_2_17
#  => => # _x86_64.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manyli
#  => => # nux2014_x86_64.whl.metadata (5.7 kB)
#  => => # Collecting cycler>=0.10 (from matplotlib)
#  => => #   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# [+] Building 5.2s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                4.8s
#  => => # _x86_64.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manyli
#  => => # nux2014_x86_64.whl.metadata (5.7 kB)
#  => => # Collecting cycler>=0.10 (from matplotlib)
#  => => #   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
#  => => # Collecting fonttools>=4.22.0 (from matplotlib)
# [+] Building 5.4s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                4.9s
#  => => # 030c26102634447b2c9ad44b3b6b/fonttools-4.42.0-cp311-cp311-manylinux_2_
#  => => # 17_x86_64.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading fonttools-4.42.0-cp311-cp311-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl.metadata (150 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 4.1 MB/s e
#  => => # ta 0:00:00
# [+] Building 5.5s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                5.1s
#  => => # 030c26102634447b2c9ad44b3b6b/fonttools-4.42.0-cp311-cp311-manylinux_2_
#  => => # 17_x86_64.manylinux2014_x86_64.whl.metadata
#  => => #   Downloading fonttools-4.42.0-cp311-cp311-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl.metadata (150 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 4.1 MB/s e
#  => => # ta 0:00:00
# [+] Building 5.6s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                5.2s
#  => => # inux2014_x86_64.whl.metadata (150 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 4.1 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting kiwisolver>=1.0.1 (from matplotlib)
#  => => #   Downloading kiwisolver-1.4.4-cp311-cp311-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl (1.4 MB)
# [+] Building 5.8s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                                5.3s
#  => => # inux2014_x86_64.whl.metadata (150 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.6/150.6 kB 4.1 MB/s e
#  => => # ta 0:00:00
#  => => # Collecting kiwisolver>=1.0.1 (from matplotlib)
#  => => #   Downloading kiwisolver-1.4.4-cp311-cp311-manylinux_2_17_x86_64.manyl
#  => => # inux2014_x86_64.whl (1.4 MB)
# [+] Building 5.9s (7/8)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
# ...
#  => => exporting layers                                                    0.1s
# [+] Building 35.0s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 35.2s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     0.4s
#  => => exporting layers                                                    0.4s
# [+] Building 35.3s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 35.5s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     0.7s
#  => => exporting layers                                                    0.7s
# [+] Building 35.6s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 35.8s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     1.0s
#  => => exporting layers                                                    1.0s
# [+] Building 35.9s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 36.1s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     1.3s
#  => => exporting layers                                                    1.3s
# [+] Building 36.2s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     1.5s
#  => => exporting layers                                                    1.5s
# [+] Building 36.4s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     1.6s
#  => => exporting layers                                                    1.6s
# [+] Building 36.5s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     1.8s
#  => => exporting layers                                                    1.8s
# [+] Building 36.7s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     1.9s
#  => => exporting layers                                                    1.9s
# [+] Building 36.8s (8/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    2.1s
# [+] Building 36.9s (9/9) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 37B                                        0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/jupyter/base-notebook:latest    0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 910.06kB                                      0.1s
#  => [1/4] FROM docker.io/jupyter/base-notebook:latest                      0.0s
#  => CACHED [2/4] WORKDIR /home/jovyan/work                                 0.0s
#  => [3/4] COPY . /home/jovyan/work                                         0.2s
#  => [4/4] RUN pip install pandas matplotlib                               34.3s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    2.1s
#  => => writing image sha256:bd735acb6f7ba681efc96e94b49bf3fffc09383740d02  0.0s
#  => => naming to docker.io/library/jupyter_server                          0.0s

# %% [markdown]
# The build process will create a Docker image with your Jupyter Notebook server configuration.
#
# To run the Jupyter Notebook server in a container based on the image you just built, use the following command:

# %%
# !docker run -p 8889:8889 jupyter_server
# Out:
# [I 2023-08-07 22:01:17.926 ServerApp] Package notebook took 0.0000s to import
# [I 2023-08-07 22:01:17.944 ServerApp] Package jupyter_lsp took 0.0174s to import
# [W 2023-08-07 22:01:17.944 ServerApp] A `_jupyter_server_extension_points` function was not found in jupyter_lsp. Instead, a `_jupyter_server_extension_paths` function was found and will be used for now. This function name will be deprecated in future releases of Jupyter Server.
# [I 2023-08-07 22:01:17.967 ServerApp] Package jupyter_server_terminals took 0.0220s to import
# [I 2023-08-07 22:01:17.968 ServerApp] Package jupyterlab took 0.0000s to import
# [I 2023-08-07 22:01:18.591 ServerApp] Package nbclassic took 0.0096s to import
# [W 2023-08-07 22:01:18.593 ServerApp] A `_jupyter_server_extension_points` function was not found in nbclassic. Instead, a `_jupyter_server_extension_paths` function was found and will be used for now. This function name will be deprecated in future releases of Jupyter Server.
# [I 2023-08-07 22:01:18.593 ServerApp] Package notebook_shim took 0.0000s to import
# [W 2023-08-07 22:01:18.593 ServerApp] A `_jupyter_server_extension_points` function was not found in notebook_shim. Instead, a `_jupyter_server_extension_paths` function was found and will be used for now. This function name will be deprecated in future releases of Jupyter Server.
# [I 2023-08-07 22:01:18.594 ServerApp] jupyter_lsp | extension was successfully linked.
# [I 2023-08-07 22:01:18.598 ServerApp] jupyter_server_terminals | extension was successfully linked.
# [I 2023-08-07 22:01:18.603 ServerApp] jupyterlab | extension was successfully linked.
# [I 2023-08-07 22:01:18.606 ServerApp] nbclassic | extension was successfully linked.
# [I 2023-08-07 22:01:18.610 ServerApp] notebook | extension was successfully linked.
# [I 2023-08-07 22:01:18.611 ServerApp] Writing Jupyter server cookie secret to /home/jovyan/.local/share/jupyter/runtime/jupyter_cookie_secret
# [I 2023-08-07 22:01:18.954 ServerApp] notebook_shim | extension was successfully linked.
# [I 2023-08-07 22:01:18.975 ServerApp] notebook_shim | extension was successfully loaded.
# [I 2023-08-07 22:01:18.977 ServerApp] jupyter_lsp | extension was successfully loaded.
# [I 2023-08-07 22:01:18.978 ServerApp] jupyter_server_terminals | extension was successfully loaded.
# [I 2023-08-07 22:01:18.983 LabApp] JupyterLab extension loaded from /opt/conda/lib/python3.11/site-packages/jupyterlab
# [I 2023-08-07 22:01:18.983 LabApp] JupyterLab application directory is /opt/conda/share/jupyter/lab
# [I 2023-08-07 22:01:18.983 LabApp] Extension Manager is 'pypi'.
# [I 2023-08-07 22:01:18.987 ServerApp] jupyterlab | extension was successfully loaded.
# [I 2023-08-07 22:01:18.992 ServerApp] nbclassic | extension was successfully loaded.
# [I 2023-08-07 22:01:19.005 ServerApp] notebook | extension was successfully loaded.
# [I 2023-08-07 22:01:19.008 ServerApp] Serving notebooks from local directory: /home/jovyan/work
# [I 2023-08-07 22:01:19.008 ServerApp] Jupyter Server 2.7.0 is running at:
# [I 2023-08-07 22:01:19.008 ServerApp] http://33b81f51d921:8889/tree?token=96a256455fffcebdef1f5c13a9f41adef5f0117701945b11
# [I 2023-08-07 22:01:19.008 ServerApp]     http://127.0.0.1:8889/tree?token=96a256455fffcebdef1f5c13a9f41adef5f0117701945b11
# [I 2023-08-07 22:01:19.008 ServerApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# [C 2023-08-07 22:01:19.012 ServerApp]
#
#     To access the server, open this file in a browser:
#         file:///home/jovyan/.local/share/jupyter/runtime/jpserver-7-open.html
#     Or copy and paste one of these URLs:
#         http://33b81f51d921:8889/tree?token=96a256455fffcebdef1f5c13a9f41adef5f0117701945b11
#         http://127.0.0.1:8889/tree?token=96a256455fffcebdef1f5c13a9f41adef5f0117701945b11
# [I 2023-08-07 22:01:19.872 ServerApp] Skipped non-installed server(s): bash-language-server, dockerfile-language-server-nodejs, javascript-typescript-langserver, jedi-language-server, julia-language-server, pyright, python-language-server, python-lsp-server, r-languageserver, sql-language-server, texlab, typescript-language-server, unified-language-server, vscode-css-languageserver-bin, vscode-html-languageserver-bin, vscode-json-languageserver-bin, yaml-language-server
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# ^C
# [I 2023-08-07 22:01:42.764 ServerApp] Interrupted...
#
#   _   _          _      _
#  | | | |_ __  __| |__ _| |_ ___
#  | |_| | '_ \/ _` / _` |  _/ -_)
#   \___/| .__/\__,_\__,_|\__\___|
#        |_|
#
# Read the migration plan to Notebook 7 to learn about the new features and the actions to take if you are using extensions.
#
# https://jupyter-notebook.readthedocs.io/en/latest/migrate_to_notebook7.html
#
# Please note that updating to Notebook 7 might break some of your extensions.

# %% [markdown]
# The **-p 8889:8889** maps port 8889 from the container to port 8889 on the host machine. You can then access the Jupyter Notebook server by opening a web browser and navigating to http://localhost:8889 in the host machine. You'll see the Jupyter Notebook interface and can start working with your notebooks.

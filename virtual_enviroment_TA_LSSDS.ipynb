# %%
# !git
# Out:
# usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#            [-p | --paginate | -P | --no-pager] [--no-replace-objects] [--bare]
#            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#            [--super-prefix=<path>] [--config-env=<name>=<envvar>]
#            <command> [<args>]
#
# These are common Git commands used in various situations:
#
# start a working area (see also: git help tutorial)
#    clone     Clone a repository into a new directory
#    init      Create an empty Git repository or reinitialize an existing one
#
# work on the current change (see also: git help everyday)
#    add       Add file contents to the index
#    mv        Move or rename a file, a directory, or a symlink
#    restore   Restore working tree files
#    rm        Remove files from the working tree and from the index
#
# examine the history and state (see also: git help revisions)
# ...

# %% [markdown]
# # Teacher assistants session: Environment setup
#
# **Written by**
#
# Nicolás Monsalves<br>
# Universidad de La Serena, Chile<br>
# nicolas.monsalves@userena.cl<br>
#
# Martina Cádiz-Leyton<br>
# Universidad de Concepcion, Chile<br>
# mcadiz2018@inf.udec.cl<br>
#
#
# Catherine Benavides<br>
# Universidad de Chile, Chile<br>
# catherine.benavides@ug.uchile.cl<br>
#
# and notes from Matthew Graham

# %% [markdown]
# # Welcome to LSSDS!
#
# LSSDS attracts students with diverse backgrounds, interests, and goals. This also means that students' experiences with the course prerequisites are quite varied. Some may, for example, have extensive coding experience, but perhaps can't remember how to represent a projection with linear algebra. Others may have a strong statistics background, but are less confident when it comes to Python.
#
# Homework 0 is a way to assess your comfort with the skills and concepts foundational to the course. It is not expected that you should be able to recall everything from memory while working through the assignment. What maters is the ability to use the context and resources available to fill in any gaps and work toward your goal. This is what we do 'in the real world' after all! However, if you do find HW0 to be too challenging,

# %% [markdown]
# # Python
# **Why python!**
#
# Our primary tool in this course is the Python programming language. It has a reputaion for having a clean, readable syntax, sometimes described as being "like pseudocode you can run." Python is also distributed with a large [standard library](https://docs.python.org/3/library/index.html). This "batteries included" approach has made Python one of the most popular general purpose programming languages around today.
#
# As a result, the community of Python users is enormous with many contributing to open source projects. The Python Package Index ([PyPi](https://pypi.org/)) hosts over 562,903 different projects! And that's not all. There are also specialized repositories for scientific computing packages, such as [conda-forge](https://conda-forge.org/#page-top). And then there are all the other public projects hosted on **Github, Gitlab, and elsewhere**. Python gives us access to this software ecosystem.

# %% [markdown]
# With Python we have access to modules from the standard Python library like `datetime`, `math`, `collections`, `itertools`, `re`, etc. But we'd also like to install 3rd party packages (Tensorflow, Numpy, Scipy, etc.).
#
#
# ---
#
#
# ⚠️ However, we need to take care in how we install packages because ⚠️:
#
# ---
#
#
# 1. Some of your coding projects will require conflicting versions of the same package that can't coexist.
# 2. If your operating system makes use of Python, altering the system installation could have unintended consequences.
# 3. We can't hope to make our results reproducible without documenting the specific software versions that produced them.
#
# What we need is some way to easily create and manage multiple isolated Python installations, each with their own set of package dependencies.

# %% [markdown]
# ## Virtual Environments
# [**Keep your Python's isolated from one another**]
#
# <img src="https://blog.debugeverything.com/wp-content/uploads/2021/04/python-virtualenv-project-structure.jpg" alt="drawing" width="400" height="300">
#
# A [virtual environment](https://docs.python.org/3/library/venv.html#venv-def) is a self-contained directory tree that contains a Python installation for a particular version of Python, plus a number of additional packages. Just what we're looking for!
#
# Most Python distributions will include:
# * [venv](https://docs.python.org/3/library/venv.html#module-venv) - to create and manage virtual environments
# * [pip](https://docs.python.org/3/installing/index.html#installing-index) - to download and manage 3rd party packages (from PyPi by default)
#
# For more information on these tools, you can read the Python tutorial entry on [virtual environments & packages](https://docs.python.org/3/tutorial/venv.html?highlight=pip)
#
# But we can generalize this idea of a Python virtual environment to *all languages*. This is useful because our data science projects may have dependencies outside of Python itself.

# %% [markdown]
# # LSSDS logistic
#
# The codes can be implemented both **locally and in cloud**. In this tutorial, we will demonstrate how to work in both ways; however, for the school, it is expected that you use Colab (Google's cloud service) to develop your assignments and projects. Nevertheless, there is no problem if you choose to use what suits you best.

# %% [markdown]
# ## Locally (on your PC 💻)
#
# We recommend you to use Anaconda or Miniconda.
#
# [Link Download](https://docs.anaconda.com/anaconda/install/index.html)             |  Jupyter Notebook integrated in Anaconda
# :-------------------------:|:-------------------------:
# <img src="https://assets.anaconda.com/production/anaconda-meta.jpg?w=1200&h=630&q=82&auto=format&fit=clip&dm=1632326952&s=2b336a00fa13405f84ce2f5b74e21fee" alt="drawing" width="400" height="300">  |  <img src="https://jupyter.org/assets/share.png"   width="400" height="300">
#
# Anaconda is a powerful distribution of the Python programming language tailored for data science, scientific computing, and machine learning. It includes its own Python interpreter, along with the Conda package manager, enabling easy installation, management, and creation of **isolated environments** with specific library dependencies.

# %% [markdown]
# * You can work in a **Text Editor** or an **Integrated Development Environment** (IDE), for example:<p>
#
#     - Visual Studio Code (code editor)
#     - Sublime text (code editor)
#     - Spyder (IDE)
#     - PyCharm (IDE)
#     - Among others...

# %% [markdown]
# ### Installation tutorial

# %% [markdown]
# Here's a step-by-step guide on how to install Miniconda on Linux:
#
# 1. Download Miniconda: You can download it from the official site  https://docs.conda.io/en/latest/miniconda.html or use the command below:
# ```sh
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# ```
# 2. Set Execution Permissions: Grant the downloaded .sh file the necessary permissions to execute using the following command:
# ```sh
# chmod 700 Miniconda3-latest-Linux-x86_64.sh
# ```
# 3. Begin Installation: Run the file and follow the on-screen prompts to continue with the installation:
# ```sh
# ./Miniconda3-latest-Linux-x86_64.sh
# ```

# %% [markdown]
# Here's a step-by-step guide for installing miniconda on Windows:<p>
#
# 1. **Download Miniconda**:
# Go to the Anaconda website (https://docs.conda.io/en/latest/miniconda.html) and download the appropriate installer for your Windows version (32-bit or 64-bit).
#
# 2. **Run the Installer**:
# Once the download is complete, run the miniconda installer executable (the file you downloaded). If you have administrator privileges, it's recommended to run the installer as an administrator.
#
# 3. **Installation Setup:**
# Follow the installation instructions. You'll be asked to agree to the license agreement and choose the installation location. The default location is usually fine for most users.
#
# 4. **Advanced Options (Optional)**
# The installer might ask you to add miniconda to your system PATH environment variable. Selecting this option allows you to run miniconda commands from any Command Prompt or PowerShell window. It's generally recommended to check this option.
#
# 5. **After the Installation**:
# Once the installation is complete, you'll see a message indicating the successful installation. Open the aplication "Anaconda Prompt(miniconda3)".
#
# 6. **Testing miniconda:**
# To test whether Miniconda is installed correctly, open the PowerShell and type conda --version.

# %% [markdown]
# #Create a virtual environment with conda:
# To create a virtual environment with Conda, write the following command in your terminal:
#
# ```sh
# conda create --name myenv
# ```
# Here, "myenv" is the name of your new virtual environment. You can replace "myenv" with any name that you prefer for your environment.
#
# **Install a specific version of Python:** If you want to install a specific version of Python in your new environment, you can do so during the creation of the environment. For example, to install Python 3.8 (and other dependences), write the following command in your terminal:
# ```sh
# conda create --name lssds python=3.8 jupyter pandas scikit-learn astropy matplotlib seaborn
# ```
# Activate (or deactivate) the environment: To activate your new environment, write the following command in your terminal:
#
# ```sh
# conda activate lssds
# ```
# When you're done working in your environment, you can deactivate it by writing the following command:
# ```sh
# conda deactivate
# ```
# Install packages: To install packages in your environment, **you must first activate it** and then you can use conda install. For example, to install numpy, write the following command in your terminal:
#
# ```sh
# conda install numpy
# ```
# See all your virtual environments: To see all your virtual environments, write the following command in your terminal:
#
# ```sh
# conda env list
# ```
# Remove a virtual environment: Finally, to remove a virtual environment, write the following command in your terminal:
#
# ```sh
# conda env remove --name myenv
# ```
# Export the environment to a .yml file: If you want to share your environment with others or want to recreate it later, you can export your environment into a .yml file. Write the following command in your terminal:
# ```sh
# conda env export > environment.yml
# ```
# This will create a new file called "environment.yml" in your current directory, which includes all the information needed to recreate your environment.
#
# Import an environment from a .yml file: If you want to create an environment from a .yml file, you can do so by writing the following command in your terminal:
# ```sh
# conda env create -f environment.yml --name myenv
# ```
#
# This will create a new environment based on the specifications in the "environment.yml" file.

# %% [markdown]
# *What about the usage of Jupyter Notebook that you promised us?* 🤨😔
#
# Well... Jupyter Notebook comes **pre-installed with Anaconda** (and we installed in miniconda), so once you have installed miniconda following the steps in the previous tutorial, you already have Jupyter Notebook ready to use.
# ![image.png](data:image/png;base64,...)
#  Here's how you can launch Jupyter Notebook:
#
# ```sh
# jupyer-notebook
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Cloud (highly recommended by the TAs , especially when your PC doesn't have a GPU ☁️):
#
# Colab allows anybody to write and execute arbitrary python code through the browser, and is especially well suited to machine learning, data analysis and education. More technically, Colab is a hosted Jupyter notebook service that requires no setup to use, while providing access free of charge to computing resources including GPUs.

# %% [markdown]
# In Colab bash commands can be run by prefixing the command with **!**
#
# For example, creating a directory:

# %%
# !mkdir new_directory

# %%
# !ls
# Out:
# new_directory  README.md  testing.py

# %% [markdown]
# Cloning a git repository:

# %%
# !git clone https://github.com/MartinaCadiz/my_project.git
# Out:
# Cloning into 'my_project'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.

# %% [markdown]
# Also you can install libraries:

# %%
# !pip install pandas

# %%
import pandas as pd

df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# One of the most significant benefits of using Colab is its integration with Google Drive. This integration allows you to access your Google Drive files directly from the Colab environment

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # What is Git? A Beginner's Guide to Git Version Control
#
# Git is a free and open-source distributed version control system designed to handle various projects with speed and efficiency. GitHub, on the other hand, is a web-based hosting service for Git repositories. It offers all the distributed revision control and source code management (SCM) functionality of Git, along with its own additional features.
#
# With these tools, users can:
#
# - Write code from multiple computers and create different versions of their programs.
# - Revert changes if they've uploaded problematic code.
# - Collaborate with other team members and more.
# - They are essential for tracking different versions of code and facilitating collaboration among developers.
#
# Github logo          |  Main idea
# :-------------------------:|:-------------------------:
# <img src="https://1000logos.net/wp-content/uploads/2021/05/GitHub-logo.png" alt="drawing" width="250" height="200">  |  <img src="https://www.freecodecamp.org/news/content/images/2021/03/1_BdQ8MuiohcSVp20163pEig.png"   width="500" height="300">
#
#
# The first thing you need to do is to:
#
# * [Create a Github account](https://github.com/)
# * Install Git:
#   * [Install git on Ubuntu](https://phoenixnap.com/kb/how-to-install-git-on-ubuntu)
#   *  [Install git on Windows ](https://phoenixnap.com/kb/how-to-install-git-windows)
#   *  [Install git on Mac ](https://phoenixnap.com/kb/install-git-on-mac)

# %% [markdown]
# After installing Git, the next step is to create a local Git repository. In this tutorial, we will demonstrate how to achieve this using the git bash terminal.
#
# ## Git Repository
# It tracks and saves the history of changes made to the files in your project. To simplify the process, you can work with your project offline (locally) and later upload it to the online database, which is GitHub.

# %% [markdown]
# ---
#
#
# First you should create a **remote Git repository**.
#
# Go to your account and select the **📗New**

# %% [markdown]
# ![Captura de pantalla 2023-08-02 155143.png](data:image/png;base64,...)

# %% [markdown]
# It will display the following creation page:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Now you have successfully created a **remote Git repository** called **my_project**. Where you will be able to see this page in Github:
#
# ![image.png](data:image/png;base64,...)
#
#
# This repository creates by default a README.md file. This file is often the first item a visitor will see when visiting your repository. README files typically include information about your project.

# %% [markdown]
# ---
#
#
# The second step is to create a directory where you want to keep the project in your local machine. Write the following commands:

# %% [markdown]
# ```
# mkdir my_project
# cd my_project
#
# ```
#
# Git bash terminal:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#
# The last step is to use **git clone** command to clone an existing repository and copy it to your local machine. You can extract the git clone link of your remote repository in the highlighted section:
#
# ![Captura de pantalla 2023-08-02 165841.png](data:image/png;base64,...)

# %% [markdown]
# After getting the link, open your git bash terminal and use the **git clone** command:
#
#
# ```
# git clone [url] [directory]
# ```

# %% [markdown]
# For example, writing it in your git bash terminal:
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If you want to test whether it works, simply navigate to the **my_project** directory and check if the **README.md** file has appeared. 😄
#
#
# ---

# %% [markdown]
# ## Configuring the repository
#
# To add an author name to all the commits in the current local repository:
#
#
# ```
# git config --global user.name "[your_name]"
# ```
# To add an email address to all the commits by the current user:
#
#
#
# ```
# git config --global user.email "[email_address]"
# ```

# %% [markdown]
# For example, writing it in your git bash terminal:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Saving changes
#
# To understand how to transfer files from the local to the remote, it's crucial to comprehend the Git workflow, which involves:
#
#  <img src="https://geo-python.github.io/site/2018/_images/Git_illustration.png"   width="500" height="300">
#
# The staging area gives you the opportunity to review and fine-tune your changes before committing them.
#
# Making changes to the Git repository is done by using **git add** and **git commit** commands.

# %% [markdown]
# Now with **git add** command, I will adds files to the staging area:
#
# ```
# git add .
# ```
# While the **git commit** command applies the staged changes to the repository, this command line allows you to add a description of your changes:
#
# ```
# git commit -m "descriptive message"
# ```

# %% [markdown]
# ## Enabling Collaboration
#
# Git allows you to copy and share repositories with other developers by using the **git push** and **git pull** commands.

# %% [markdown]
# The **git push** command lets you share all the commits and files in the current repository with the remote repository:
#
#
# ```
# git push [remote repository] [branch name]
# ```
#
# Use the **git pull** command to copy the content of a remote repository and merge it with your local copy:
#
# ```
# git pull [remote repository]
# ```

# %% [markdown]
# Git offers a multitude of possibilities and tools. Here is a [git cheat sheet](https://education.github.com/git-cheat-sheet-education.pdf), which includes more interesting commands 🤩😎.
